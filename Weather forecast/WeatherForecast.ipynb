# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio
import matplotlib.pyplot as plt
import seaborn as sns

# Set renderer to display plots in VS Code notebooks
pio.renderers.default = 'notebook_connected'

# %%
data = pd.read_csv('Train.csv')
data.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
data.describe()
# Out:
#           meantemp     humidity   wind_speed  meanpressure
# count  1462.000000  1462.000000  1462.000000   1462.000000
# mean     25.495521    60.771702     6.802209   1011.104548
# std       7.348103    16.769652     4.561602    180.231668
# min       6.000000    13.428571     0.000000     -3.041667
# 25%      18.857143    50.375000     3.475000   1001.580357
# 50%      27.714286    62.625000     6.221667   1008.563492
# 75%      31.305804    72.218750     9.238235   1014.944901
# max      38.714286   100.000000    42.220000   7679.333333

# %%
data.info()

# %%
figure = px.line(data, x="date", 
                 y="meantemp", 
                 title='Mean Temperature in Delhi Over the Years')
figure.show()

# %%
figure = px.line(data, x="date", 
                 y="humidity", 
                 title='Mean Temperature in Delhi Over the Years')
figure.show()

# %%
figure = px.line(data, x="date", 
                 y="wind_speed", 
                 title='Mean Temperature in Delhi Over the Years')
figure.show()

# %%
figure = px.line(data, x="date", 
                 y="meanpressure", 
                 title='Mean Temperature in Delhi Over the Years')
figure.show()

# %%
figure = px.scatter(data_frame = data, x="humidity",
                    y="meantemp", size="meantemp", 
                    trendline="ols", 
                    title = "Relationship Between Temperature and Humidity")
figure.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="0364e512-df38-4dfe-b201-6f8201f8308e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0364e512-df38-4dfe-b201-6f8201f8308e")) {                    Plotly.newPlot(                        "0364e512-df38-4dfe-b201-6f8201f8308e",                        [{"hovertemplate":"humidity=%{x}\u003cbr\u003emeantemp=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","size":{"dtype":"f8","bdata":"...\u002fQAAAAAAAoEBAq6qqqqpqQEDbtm3btu1AQCVJkiRJkkBAJUmSJEmSP0AAAAAAADBAQGZmZmZmZkBAAAAAAAAAP0Crqqqqqio\u002fQFRVVVVV1T1AAAAAAAAAPUAAAAAAAMA9QAAAAAAAQEBAAAAAAADgPEAAAAAAAMA\...\u002fQAAAAAAAYEBAbtu2bdu2P0Crqqqqqqo\...\u002fQAAAAAAA4D9AAAAAAADAPUAlSZIkSZI9QAAAAAAAwD9AAAAAAABgP0AAAAAAAIA+QAAAAAAAAD5AAAAAAACgPUAAAAAAAAA8QAAAAAAAQDlAAAAAAADgOkAAAAAAAIA9QAAAAAAAID9AAAAAAADgPUAAAAAAAIA\u002fQAAAAAAAMEBAAAAAAAAgP0AAAAAAAIBAQAAAAAAAoEBAAAAAAABQQUAAAAAAAIA\u002fQAAAAAAAgD9AAAAAAAAgPkAAAAAAAOA\...\\...\u002fQAAAAAAAQD9AAAAAAABQQEAAAAAAAEA\u002fQAAAAAAAID5AAAAAAAAAP0AAAAAAAOA+QAAAAAAAEEBAAAAAAAAQQUBu27Zt27ZBQAAAAAAAEEFAAAAAAACQQUAAAAAAAJBBQAAAAAAAAEFAAAAAAACQQEAAAAAAAMA7QAAAAAAAoD1AAAAAAACAPEAAAAAAAAA+QAAAAAAAoEBAAAAAAACwQUAAAAAAAIA\\\...\u002fQAAAAAAAoD9AAAAAAAAAP0AAAAAAAEA\...\u002fQAAAAAAAkEBAAAAAAADQQEAAAAAAANhBQFVVVVVVVUFAAAAAAABQQUAAAAAAAABBQAAAAAAACEFAAAAAAAAAQUAAAAAAAKBAQKuqqqqq6j9AAAAAAABQP0AAAAAAAMA\...\u002fQAAAAAAAIDtAAAAAAAAgPECrqqqqqqo7QAAAAAAAKEBAAAAAAAAYQUARERERERFBQAAAAAAAEEFAAAAAAADgP0AAAAAAAHA\\u002fQNu2bdu2LT5AhetRuB6FP0CO4ziO4zg\u002fQJIkSZIkyT9AMzMzMzOzQEAlSZIkSZI9QArXo3A9Cj5AJrSX0F5CO0D2KFyPwvU7QJze9KY3vT5AUV5DeQ3lPkAUO7ETO7E\u002fQDyxEzuxEz9AAAAAAABgPkCamZmZmRk\u002fQKuqqqqq6j9A5TiO4ziOPkCxEzuxEzs\u002fQAAAAAAAAD9ASZIkSZKkP0BERERERERAQLdt27Zt2z5Auuiiiy66P0BmZmZmZmY\u002fQHZiJ3ZiJ0BAAAAAAAAgQEAAAAAAADBAQI7jOI7juEBArkfhehSuQECZ0F5Cewk+QAAAAAAAAD9APQrXo3A9P0CxkIUsZCE\...\..."},"sizemode":"area","sizeref":0.09678571428571431,"symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":{"dtype":"f8","bdata":"...\ ...

# %%
data["date"] = pd.to_datetime(data["date"], format = '%Y-%m-%d')
data['year'] = data['date'].dt.year
data["month"] = data["date"].dt.month
data.head()
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure  year  month
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667  2013      1
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000  2013      1
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667  2013      1
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667  2013      1
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000  2013      1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   datetime64[ns]
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
#  5   year          1462 non-null   int32
#  6   month         1462 non-null   int32
# dtypes: datetime64[ns](1), float64(4), int32(2)
# memory usage: 68.7 KB

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(15, 10))
plt.title("Temperature Change in Delhi Over the Years")
sns.lineplot(data = data, x='month', y='meantemp', hue='year')
plt.show()

# %%
# The prophet model accepts time data named as “ds”, and labels as “y”. So let’s convert the data into this format:
forecast_data = data.rename(columns = {"date": "ds", 
                                       "meantemp": "y"})
print(forecast_data)
# Out:
#              ds          y    humidity  wind_speed  meanpressure  year  month
# 0    2013-01-01  10.000000   84.500000    0.000000   1015.666667  2013      1
# 1    2013-01-02   7.400000   92.000000    2.980000   1017.800000  2013      1
# 2    2013-01-03   7.166667   87.000000    4.633333   1018.666667  2013      1
# 3    2013-01-04   8.666667   71.333333    1.233333   1017.166667  2013      1
# 4    2013-01-05   6.000000   86.833333    3.700000   1016.500000  2013      1
# ...         ...        ...         ...         ...           ...   ...    ...
# 1457 2016-12-28  17.217391   68.043478    3.547826   1015.565217  2016     12
# 1458 2016-12-29  15.238095   87.857143    6.000000   1016.904762  2016     12
# 1459 2016-12-30  14.095238   89.666667    6.266667   1017.904762  2016     12
# 1460 2016-12-31  15.052632   87.000000    7.325000   1016.100000  2016     12
# 1461 2017-01-01  10.000000  100.000000    0.000000   1016.000000  2017      1
#
# [1462 rows x 7 columns]

# %%
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly
model = Prophet()
model.fit(forecast_data)
forecasts = model.make_future_dataframe(periods=6000)
predictions = model.predict(forecasts)
plot_plotly(model, predictions)
# Out:
# 13:10:02 - cmdstanpy - INFO - Chain [1] start processing
# 13:10:02 - cmdstanpy - INFO - Chain [1] done processing
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="f50ede27-4e8a-4ee3-805f-f87d8000a1a9" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f50ede27-4e8a-4ee3-805f-f87d8000a1a9")) {                    Plotly.newPlot(                        "f50ede27-4e8a-4ee3-805f-f87d8000a1a9",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","x":["